# %% [markdown]
# # 서울시 범죄현황 데이터를 통한 CCTV 설치 필요지역 파악하기

# %% [markdown]
# ## 1. 서울시 자치구별 범죄현황 데이터 읽어오기

# %%
import pandas as pd

# Colab에서는 파일의경로명을 해당 파일에서 점 세개 버튼의 경로 복사로 복사해 사용
#예) Crime_Seoul = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AI_2주차_실습파일_오프라인/서울시 5대 범죄 발생 현황 통계.txt'.......)

# 강의자료 3, 7쪽 참조, 여기서 불러오로 파일은 encodind = 'utf-8' 또는 생략해도 됨
#('./서울시 5대 범죄 발생 현황 통계.txt', sep= '\t', encoding= 'utf-8')

Crime_Gwangju = pd.read_excel('죄종별_범죄발생_및_검거현황_광주청__20250312153338.xlsx')
Crime_Gwangju
# Out:
# C:\Users\108-0\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     죄종별(1)     죄종별(2)  2024.3/4 2024.3/4.1      2024.3/4.2 2024.3/4.3  \
# 0   죄종별(1)     죄종별(2)  발생건수 (건)   검거건수 (건)  발생건수대비검거건수 (%)   검거인원 (명)
# 1       총계         소계     11874       9963            83.9       9551
# 2     강력범죄         소계       158        146            92.4        157
# 3      NaN       살인기수         1          1             100          1
# 4      NaN      살인미수등         1          1             100          1
# 5      NaN         강도         8          9           112.5         16
# 6      NaN         강간        26         22            84.6         23
# 7      NaN       유사강간        10          9              90          9
# 8      NaN       강제추행       101         93            92.1         95
# 9      NaN  기타강간·강제추행         1          1             100          1
# 10     NaN         방화        10         10             100         11
# 11    절도범죄         소계      1660       1288            77.6        802
# 12    폭력범죄         소계      1546       1411            91.3       1766
# 13     NaN         상해       130        128            98.5        164
# 14     NaN         폭행       841        824              98       1041
# 15     NaN      체포·감금         5          3              60          3
# 16     NaN         협박       157        152            96.8        146
# 17     NaN      약취·유인         2          3             150          6
# 18     NaN      폭력행위등        51         49            96.1        145
# 19     NaN         공갈        33         18            54.5         28
# 20     NaN         손괴       327        234            71.6        233
# 21    지능범죄         소계      4240       3240            76.4       2137
# 22     NaN       직무유기        11          3            27.3          5
# 23     NaN       직권남용        32          8              25         53
# 24     NaN        증수뢰         5          2              40          8
# 25     NaN         통화         2          0               -          0
# 26     NaN      문서·인장        85         76            89.4        103
# 27     NaN     유가증권인지         0          0               -          0
# 28     NaN         사기      3642       2852            78.3       1608
# 29     NaN         횡령       433        275            63.5        298
# 30     NaN         배임        30         24              80         62
# 31    풍속범죄         소계       222        193            86.9        548
# 32     NaN      성풍속범죄       157        151            96.2        159
# 33     NaN       도박범죄        65         42            64.6        389
# 34  특별경제범죄         소계       764        589            77.1        717
# 35    마약범죄         소계        65         53            81.5         73
# 36    보건범죄         소계        61         53            86.9         86
# 37    환경범죄         소계         6          6             100          7
# 38    교통범죄         소계      1565       1563            99.9       1585
# 39    노동범죄         소계        10         10             100         11
# 40    안보범죄         소계         1          2             200          2
# 41    선거범죄         소계         9         10           111.1         28
# 42    병역범죄         소계        57         50            87.7         50
# 43    기타범죄         소계      1510       1349            89.3       1582
#
#    2024.3/4.4  2024.4/4 2024.4/4.1      2024.4/4.2 2024.4/4.3 2024.4/4.4
# 0     법인체 (개)  발생건수 (건)   검거건수 (건)  발생건수대비검거건수 (%)   검거인원 (명)    법인체 (개)
# 1          52     11601       9180            79.1      10064         60
# 2           0       183        179            97.8        191          0
# 3           0         0          0               -          0          0
# 4           0         2          2             100          2          0
# 5           0         2          2             100          8          0
# 6           0        34         32            94.1         35          0
# 7           0        12         12             100         10          0
# 8           0       124        122            98.4        127          0
# 9           0         2          2             100          2          0
# 10          0         7          7             100          7          0
# 11          0      1509       1039            68.9        826          0
# 12          0      1645       1456            88.5       1832          0
# 13          0       118        118             100        136          0
# 14          0       877        858            97.8       1090          0
# 15          0         5          4              80          7          0
# 16          0       172        167            97.1        179          0
# 17          0         2          3             150          3          0
# 18          0        44         44             100        143          0
# 19          0        39         29            74.4         31          0
# 20          0       388        233            60.1        243          0
# 21          4      3610       2383              66       2187          3
# 22          0        10          3              30          2          0
# 23          0        30          2             6.7          5          0
# 24          0         5          4              80          8          0
# 25          0         4          0               -          0          0
# 26          0        92         83            90.2        108          0
# 27          0         0          0               -          0          0
# 28          4      3018       2032            67.3       1743          1
# 29          0       404        224            55.4        261          2
# 30          0        47         35            74.5         60          0
# 31          0       211        145            68.7        416          0
# 32          0       125        102            81.6        135          0
# 33          0        86         43              50        281          0
# 34         14       883        707            80.1        936         16
# 35          0        57         65             114         69          0
# 36          2        57         54            94.7         79          0
# 37          1         4          3              75          4          3
# 38          7      1858       1803              97       1842         12
# 39          0         1          1             100          1          0
# 40          0         3          3             100          4          0
# 41          0         0          0               -          0          0
# 42          0        43         37              86         36          0
# 43         24      1537       1305            84.9       1641         26

# %% [markdown]
# ## 2. 데이터 살펴보기

# %% [markdown]
# ### 2-1. 행x열 수, 열이름, 인덱스를 살펴보자

# %%
Crime_Gwangju.shape
# Out:
# (44, 12)

# %% [markdown]
# ### 2-2. 데이터의 상위 5행과 하위 5행을 살펴보자

# %%
Crime_Gwangju.index
# Out:
# RangeIndex(start=0, stop=44, step=1)

# %%
Crime_Gwangju.columns
# Out:
# Index(['죄종별(1)', '죄종별(2)', '2024.3/4', '2024.3/4.1', '2024.3/4.2',
#        '2024.3/4.3', '2024.3/4.4', '2024.4/4', '2024.4/4.1', '2024.4/4.2',
#        '2024.4/4.3', '2024.4/4.4'],
#       dtype='object')

# %% [markdown]
# ### 2-3. 데이터의 타입, 아이템수, 누락데이터 수 등을 살펴보자

# %%
Crime_Gwangju.head()
# Out:
#    죄종별(1)  죄종별(2)  2024.3/4 2024.3/4.1      2024.3/4.2 2024.3/4.3 2024.3/4.4  \
# 0  죄종별(1)  죄종별(2)  발생건수 (건)   검거건수 (건)  발생건수대비검거건수 (%)   검거인원 (명)    법인체 (개)
# 1      총계      소계     11874       9963            83.9       9551         52
# 2    강력범죄      소계       158        146            92.4        157          0
# 3     NaN    살인기수         1          1             100          1          0
# 4     NaN   살인미수등         1          1             100          1          0
#
#    2024.4/4 2024.4/4.1      2024.4/4.2 2024.4/4.3 2024.4/4.4
# 0  발생건수 (건)   검거건수 (건)  발생건수대비검거건수 (%)   검거인원 (명)    법인체 (개)
# 1     11601       9180            79.1      10064         60
# 2       183        179            97.8        191          0
# 3         0          0               -          0          0
# 4         2          2             100          2          0

# %% [markdown]
# ## 3. CCTV 데이터 정리하기

# %% [markdown]
# ### 3.1 데이터의 컬럼 이름을 변경해보자

# %%
#데이터의 열이름 변경:
#'자치구' -> '구별',
#'합계' -> '발생합계', '합계.1' -> '검거합계',
#'살인.1'-> '살인검거',
#'강도.1' -> '강도검거',
#'강간강제추행.1' -> '강간강제추행검거',
#'절도.1' -> '절도검거',
#'폭력.1' -> '폭력검거'

# %% [markdown]
# ### 3.2 불필요한 행과 열을 삭제하자

# %%
#'기간'열 삭제 (columns='기간', axis=1, inplace=True)

# %%
#0,1행 삭제 (index=[0,1], axis=0, inplace=True)

# %%
#기존 인덱스를 버리고 인덱스 0부터 다시 설정 (drop=True, inplace=True)

# %% [markdown]
# ## 4. 범죄현황 데이터 자세히 보기

# %% [markdown]
# ### 4-1. 범죄발생이 가장 많은/적은 상위 5개 구는 어디일까?

# %%
#'범죄발생'이 가장 많은 구, 데이터 '발생합계'열을 기준으로 내림차순 정렬하기

# %%
#범죄발생이 가장 적은 구, 데이터 '발생합계'열을 기준으로 오름차순 정렬하기

# %% [markdown]
# ### 4-2 각 범죄별 검거율을 계산하여 검거율 열을 추가하자

# %%
# 각 컬럼의 데이터 타입을 확인
# 검거율을 계산하기 위해서는 데이터가 정수형이거나 실수형이여야 함
# 이 정수형이 아니라 문자열 형임을 알수 있다. 문자열 형은 수학연산이 불가
Crime_Seoul.info()

# %%
#각 열의 문자열 형의 데이터를 정수형으로 변경
Crime_Seoul = Crime_Seoul.astype({'발생합계':'int64', '검거합계':'int64',
                                  '살인':'int64', '살인검거':'int64',
                                  '강도':'int64', '강도검거':'int64',
                                  '강간강제추행':'int64', '강간강제추행검거':'int64',
                                  '절도':'int64', '절도검거':'int64',
                                  '폭력':'int64', '폭력검거':'int64'})
Crime_Seoul.head()

# %%
# 각 컬럼의 데이터 타입이 정수형으로 변경되었음 확인

Crime_Seoul.info()

# %%
#검거 수/발생 수 * 100
#예시) Crime_Seoul['검거율'] = Crime_Seoul['검거합계']/ Crime_Seoul['발생합계']  * 100
#예시) Crime_Seoul['살인검거율'] = Crime_Seoul['살인검거']/ Crime_Seoul['살인']  * 100

Crime_Seoul['검거율'] = 
Crime_Seoul['살인검거율'] = 
Crime_Seoul['강도검거율'] = 
Crime_Seoul['강간강제추행검거율'] = 
Crime_Seoul['절도검거율'] = 
Crime_Seoul['폭력검거율'] = 
                    
Crime_Seoul.head()

# %% [markdown]
# ### 4-3. 각 범죄의 검거수를 삭제하자.

# %%
#각 범죄의 검거 열은 삭제, 검거수는 검거율로 대체해 사용 
#(columns=['살인검거','강도검거','강간강제추행검거','절도검거', '폭력검거'], axis=1, inplace=True)

# %% [markdown]
# ### 4-4. 범죄의 검거율이 가장 높은/낮은 상위 5개구는 어디일까?

# %%
#범죄 검거율이 가장 높은 구, 데이터 '검거율'열을 기준으로 정렬하기

# %%
#범죄 검거율이 가장 낮은 구, 데이터 '검거율'열을 기준으로 정렬하기

# %% [markdown]
# ## 5. 인구수와 CCTV수 데이터와 범죄 현황 데이터 합치기

# %% [markdown]
# ### 5-1 인구수와 CCTV 수 데이터 가져오기

# %%
# 서울시 자치구별 CCTV 현황 분석에서 정리하여 저장했던 'CCTV_pop.xlsx' 액셀 파일 열기

CCTV_pop = pd.read_excel('./CCTV_pop.xlsx')
CCTV_pop.head()

# %%
# CCTV_pop 데이터에서 '총계','인구수' 열만 가져와서 추가하기 
Crime_Seoul['CCTV수']=CCTV_pop['총계']
Crime_Seoul['인구수']=CCTV_pop['인구수']
Crime_Seoul.head()

# %%
#구별로 인덱스 설정
Crime_Seoul.set_index('구별', inplace=True)
Crime_Seoul.head()

# %% [markdown]
# ## 5. 범죄 데이터 시각화 하기

# %%
#한글 폰트 깨짐 방지 코드
import matplotlib.pyplot as plt
import seaborn as sns

import platform
path = "c:/windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else :
    print('Unknown system... sorry~~~')    

'''
#코랩일 경우 위의 코드는 주석처리 아래의 코드로 실행
적용이 안되면 상단 런타임 메뉴에서 다시시작 및 모두실행으로 실행
그래도 안되면 런타임 메뉴에서 런타임 다시시작 -> 다시시작 및 모두실행

#한글 폰트 깨짐 방지 코드
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib as mpl 
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm  

# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
mpl.rcParams['axes.unicode_minus'] = False
'''

# %% [markdown]
# ### 5.1 범죄 발생수가 가장 많은 구는 어디인가?

# %%
#막대 그래프 그리기
# '발생합계로 소팅하여 막대 그래프 그리기

# %% [markdown]
# ### 5.2 범죄 검거율이 가장 높은 구는 어디인가?

# %%
#막대 그래프 그리기
# '검거율'로 소팅하여 막대 그래프 그리기

# %% [markdown]
# ### 5.3 CCTV수가 가장 많은 구는 어디일까?

# %%
#막대 그래프 그리기
# 'CCTV수'로 소팅하여 막대 그래프 그리기

# %% [markdown]
# ### 5.4 강도, 살인, 폭력은 어떤 관계에 있을까?

# %%
#강도, 살인, 폭력에 대한 상간관계 그래프 
#pairplot은 그리도(grid) 형태로 각 집합의 조합에 대해 히스토그램 또는 분포도를 그려주는 함수
sns.pairplot(Crime_Seoul, vars=['강도','살인','폭력'], kind='reg', height=3) #kind='reg'는 차트 종류를 산점도라는 의미
plt.show()

# %% [markdown]
# ### 5.5 살인, 강도와 인구수와 CCTV수와 어떤 관계에 있을까?

# %%
#살인, 강도, 인구수, CCTV수에 대한 상간관계 그래프 
#pairplot은 그리도(grid) 형태로 각 집합의 조합에 대해 히스토그램 또는 분포도를 그려주는 함수
sns.pairplot(Crime_Seoul, x_vars=['인구수','CCTV수'], y_vars=['살인','강도'], kind='reg', height=3) #kind='reg'는 차트 종류를 산점도라는 의미
plt.show()

# %% [markdown]
# ### 5.6 인구수와 CCTV수는 살인검거율과 폭력검거율과 어떤 관계에 있을까?

# %%
#살인, 강도, 인구수, CCTV수에 대한 상간관계 그래프 
#pairplot은 그리도(grid) 형태로 각 집합의 조합에 대해 히스토그램 또는 분포도를 그려주는 함수
sns.pairplot(Crime_Seoul, x_vars=['인구수','CCTV수'], y_vars=['살인검거율','폭력검거율'], kind='reg', height=3) #kind='reg'는 차트 종류를 산점도라는 의미
plt.show()

# %%
Crime_Seoul.head()

# %%
#범죄발생수, 검거율, CCTV수, 인구수 항목만 따로 가져오기 
df = Crime_Seoul[['발생합계','검거율','CCTV수','인구수']]
df.head()
#항목별 상관관계 살펴보기, 대각선을 중심으로 대칭, 음수는 두 데이터가 음의 상관관게, 양수는 양의 상간관계,
#절대값이 1에 가까울 수록 상관도가 높음
df.corr()

# %%
#상관관계 그래프로 보기, 양의 상관관계는 녹색계열, 음의 상관관계는 보라색 계열
plt.matshow(df.corr())

# %% [markdown]
# ## 6. 위의 분석 결과를 보고 CCTV수가 범죄발생 및 검거에 미치는 영향과 CCTV 설치에 대한 자신의 생각을 아래에 정리해 보자

# %% [markdown]
# ### 나의생각 :
