# %% [markdown]
# <a href="https://colab.research.google.com/github/Eojinhee/2025-1bigdata/blob/main/%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0_7%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import plotly.express as px

# %%
px.scatter(data_frame=iris, x='sepal_width', y='sepal_length')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(x=iris['sepal_width'], y=iris['sepal_length'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(x=iris['sepal_width'], y=iris['sepal_length'], color=iris['species'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(x=iris['sepal_width'], y=iris['sepal_length'], color=iris['species'])
fig.update_layout(title_text='iris종류')
fig.update_xaxes(title_text = None)
fig.update_yaxes(title_text='Sepal Length')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
titanic= sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import plotly.express as px

# %%
px.scatter(x=titanic['who'], y=titanic['age'], color=titanic['class'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(x=titanic['who'], y=titanic['age'], color=titanic['class'])
fig.upda

# %%
import pandas as pd
인구동향 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/7주차/인구동향(출생,사망,혼인,이혼통계).xlsx')
인구동향
# Out:
#             시점  출생아수 (명)  사망자수 (명)  혼인건수 (건)  이혼건수 (건)
# 0   2001-01-01     11961      3305      6242      1940
# 1   2001-02-01     10159      3030      5454      2358
# 2   2001-03-01     10971      3397      6751      2630
# 3   2001-04-01      9950      3355      6825      2452
# 4   2001-05-01      9649      3227      8221      2591
# ..         ...       ...       ...       ...       ...
# 267 2023-04-01      3062      3998      2660       987
# 268 2023-05-01      3281      4333      3262      1186
# 269 2023-06-01      3141      4001      3087      1002
# 270 2023-07-01      3298      4088      2771      1050
# 271 2023-08-01      3249      4406      2739      1013
#
# [272 rows x 5 columns]

# %%
인구동향.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시점        272 non-null    datetime64[ns]
#  1   출생아수 (명)  272 non-null    int64
#  2   사망자수 (명)  272 non-null    int64
#  3   혼인건수 (건)  272 non-null    int64
#  4   이혼건수 (건)  272 non-null    int64
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 10.8 KB

# %%
import plotly.express as px

# %%
px.line(x=인구동향['시점'],y=인구동향['출생아수 (명)'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(x=인구동향['시점'],y=인구동향['출생아수 (명)'],markers=True)
fig.update_traces(line_color='red', line_width=3, line_dash='dot')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
혼인건수 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/7주차/2000_2022 혼인건수.xlsx')
혼인건수.head()
# Out:
#   자치구별  2000  2001  2002  2003  2004  2005  2006  2007  2008  ...  2013  2014  \
# 0  종로구  1550  1426  1368  1354  1160  1155  1043  1162  1069  ...   877   840
# 1   중구  1123  1192   991   968  1010   910  1035  1052   984  ...   860   851
# 2  용산구  2046  1839  1654  1699  1669  1702  1842  1979  1959  ...  1795  1560
# 3  성동구  2655  2975  2555  2578  2659  2686  2686  2763  2339  ...  2432  2125
# 4  광진구  3281  3213  3216  3000  2844  2801  3059  3023  2725  ...  2685  2589
#
#    2015  2016  2017  2018  2019  2020  2021  2022
# 0   806   760   700   676   590   565   478   486
# 1   916   799   792   778   722   653   590   511
# 2  1515  1366  1357  1400  1303  1175   995   948
# 3  2083  1944  2096  2000  1758  1573  1272  1179
# 4  2576  2285  2082  2164  1893  1661  1399  1317
#
# [5 rows x 24 columns]

# %%
혼인건수.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구별    25 non-null     object
#  1   2000    25 non-null     int64
#  2   2001    25 non-null     int64
#  3   2002    25 non-null     int64
#  4   2003    25 non-null     int64
#  5   2004    25 non-null     int64
#  6   2005    25 non-null     int64
#  7   2006    25 non-null     int64
#  8   2007    25 non-null     int64
#  9   2008    25 non-null     int64
#  10  2009    25 non-null     int64
#  11  2010    25 non-null     int64
#  12  2011    25 non-null     int64
#  13  2012    25 non-null     int64
#  14  2013    25 non-null     int64
#  15  2014    25 non-null     int64
#  16  2015    25 non-null     int64
#  17  2016    25 non-null     int64
#  18  2017    25 non-null     int64
#  19  2018    25 non-null     int64
#  20  2019    25 non-null     int64
#  21  2020    25 non-null     int64
# ...

# %%
px.bar(x=혼인건수['자치구별'],y=혼인건수['2022'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(x=혼인건수['자치구별'],y=혼인건수['2022'],color = 혼인건수['자치구별'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(x=혼인건수['자치구별'],y=혼인건수['2022'],color = 혼인건수['자치구별'], text_auto=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(y=혼인건수['자치구별'],x=혼인건수['2022'],color = 혼인건수['자치구별'], orientation='h',text_auto=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
혼인건수2022 = 혼인건수.sort_values(by='2022', ascending=False).head()
px.pie(names=혼인건수2022['자치구별'],values=혼인건수2022['2022'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(values=혼인건수2022['2022'], names=혼인건수2022['자치구별'], hole=0.3)
fig.update_traces(hole=.3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Bar(x=혼인건수['자치구별'], y=혼인건수['2010'], name='2010'))
fig.add_trace(go.Bar(x=혼인건수['자치구별'], y=혼인건수['2022'], name='2022'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Bar(x=혼인건수['자치구별'], y=혼인건수['2010'], name='2010'))
fig.add_trace(go.Scatter(x=혼인건수['자치구별'], y=혼인건수['2022'],mode='lines', name='2022'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_html('plotly 차트.html')

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x=혼인건수['자치구별'], y=혼인건수['2010'], name='2010'))
fig.add_trace(go.Scatter(x=혼인건수['자치구별'], y=혼인건수['2022'],mode='lines', name='2022'))
fig.update_layout(
    updatemenus=[
        dict(
            type="buttons",
            buttons = list([
                dict(label="모두 그리기", method="update", args=[{'visible':[True, True]}]),
                dict(label="2020 그리기", method="update", args=[{'visible':[True, False]}]),
                dict(label="2022 그리기", method="update", args=[{'visible':[False, True]}])
           ])
      )
    ]
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=혼인건수['자치구별'], y=혼인건수['2010'], name='2010'))
fig.add_trace(go.Scatter(x=혼인건수['자치구별'], y=혼인건수['2022'],mode='lines', name='2022'))
fig.update_layout(
    updatemenus=[
        dict(
            type="buttons",
            buttons = list([
                dict(label="Scatter 차트", method="restyle", args=["type", "scatter"]),
                dict(label="Bar 차트"    , method="restyle", args=["type", "bar"])
           ])
      )
    ]
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure()


fig.add_trace(go.Scatter(x=인구동향['시점'], y=인구동향['출생아수 (명)'], name='출생아수'))
fig.add_trace(go.Scatter(x=인구동향['시점'], y=인구동향['혼인건수 (건)'],mode='lines', name='2022'))
fig.update_layout(
    updatemenus=[
        dict(
            type="buttons",
            buttons=[
                dict(label="출생아수", method="update", args=[{'visible': [True, False]}]),
                dict(label="혼인건수", method="update", args=[{'visible': [False, True]}])
            ]
        )
    ]
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
